# %%
import numpy as np
from urllib.request import urlopen
import urllib
import matplotlib.pyplot as plt # Visuals
import seaborn as sns
import sklearn as skl
import pandas as pd
import sys
Cleveland_data_URL = 'http://archive.ics.uci.edu/ml/machine-learning-databases/heart-disease/processed.hungarian.data'
#Hungarian_data_URL = 'http://archive.ics.uci.edu/ml/machine-learning-databases/heart-disease/processed.hungarian.data'
#Switzerland_data_URL = 'http://archive.ics.uci.edu/ml/machine-learning-databases/heart-disease/processed.switzerland.data'
np.set_printoptions(threshold=sys.maxsize) #see a whole array when we output it
names = ['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach','exang', 'oldpeak', 'slope', 'ca', 'thal', 'heartdisease']
heartDisease = pd.read_csv(urlopen(Cleveland_data_URL), names = names) #gets Cleveland data
#HungarianHeartDisease = pd.read_csv(urlopen(Hungarian_data_URL), names = names) #gets Hungary data
#SwitzerlandHeartDisease = pd.read_csv(urlopen(Switzerland_data_URL), names = names) #gets Switzerland data
#datatemp = [ClevelandHeartDisease, HungarianHeartDisease,SwitzerlandHeartDisease] #combines all arrays into a list
#heartDisease = pd.concat(datatemp)#combines list into one array
heartDisease.head()
del heartDisease['ca']
del heartDisease['slope']
del heartDisease['thal']
del heartDisease['oldpeak']
heartDisease = heartDisease.replace('?', np.nan)
heartDisease.dtypes
heartDisease.columns
from pgmpy.models import BayesianModel
from pgmpy.estimators import MaximumLikelihoodEstimator, BayesianEstimator
model = BayesianModel([('age', 'trestbps'), ('age', 'fbs'), ('sex','trestbps'), ('sex', 'trestbps'),('exang','trestbps'),('trestbps','heartdisease'),('fbs','heartdisease'),('heartdisease','restecg'),('heartdisease','thalach'),('heartdisease','chol')])
# Learing CPDs using Maximum Likelihood Estimators
model.fit(heartDisease, estimator=MaximumLikelihoodEstimator)
#for cpd in model.get_cpds():
# print("CPD of {variable}:".format(variable=cpd.variable))
# print(cpd)
print(model.get_cpds('age'))
print(model.get_cpds('chol'))
print(model.get_cpds('sex'))
model.get_independencies()
# Out:
# /home/it2016b205/.local/lib/python3.7/site-packages/pgmpy/estimators/base.py:54: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   states = sorted(list(self.data.ix[:, variable].dropna().unique()))
# /home/it2016b205/.local/lib/python3.7/site-packages/pgmpy/estimators/base.py:116: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   state_count_data = data.ix[:, variable].value_counts()
# /home/it2016b205/.local/lib/python3.7/site-packages/pgmpy/estimators/MLE.py:128: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   state_counts.ix[:, (state_counts == 0).all()] = 1
# +---------+------------+
# | age(28) | 0.00383142 |
# +---------+------------+
# | age(29) | 0.00383142 |
# +---------+------------+
# | age(30) | 0.00383142 |
# +---------+------------+
# | age(31) | 0.00766284 |
# +---------+------------+
# | age(32) | 0.0153257  |
# +---------+------------+
# | age(33) | 0.00766284 |
# +---------+------------+
# | age(34) | 0.0153257  |
# +---------+------------+
# | age(35) | 0.0191571  |
# +---------+------------+
# | age(36) | 0.0191571  |
# +---------+------------+
# | age(37) | 0.0306513  |
# +---------+------------+
# | age(38) | 0.0191571  |
# +---------+------------+
# | age(39) | 0.0344828  |
# +---------+------------+
# | age(40) | 0.0191571  |
# +---------+------------+
# | age(41) | 0.0383142  |
# +---------+------------+
# | age(42) | 0.0268199  |
# +---------+------------+
# | age(43) | 0.0421456  |
# +---------+------------+
# | age(44) | 0.0268199  |
# +---------+------------+
# | age(45) | 0.0229885  |
# +---------+------------+
# | age(46) | 0.045977   |
# +---------+------------+
# | age(47) | 0.0344828  |
# +---------+------------+
# | age(48) | 0.0613027  |
# +---------+------------+
# | age(49) | 0.0421456  |
# +---------+------------+
# | age(50) | 0.045977   |
# +---------+------------+
# | age(51) | 0.0344828  |
# +---------+------------+
# | age(52) | 0.0574713  |
# +---------+------------+
# | age(53) | 0.0383142  |
# +---------+------------+
# | age(54) | 0.0842912  |
# +---------+------------+
# | age(55) | 0.0536398  |
# +---------+------------+
# | age(56) | 0.0306513  |
# +---------+------------+
# | age(57) | 0.0191571  |
# +---------+------------+
# | age(58) | 0.0344828  |
# +---------+------------+
# | age(59) | 0.0229885  |
# +---------+------------+
# | age(60) | 0.00766284 |
# +---------+------------+
# | age(61) | 0.00766284 |
# +---------+------------+
# | age(62) | 0.00766284 |
# +---------+------------+
# | age(63) | 0.00383142 |
# +---------+------------+
# | age(65) | 0.0114943  |
# +---------+------------+
# | age(66) | 0          |
# +---------+------------+
# +--------------+----------------------+----------------------+
# | heartdisease | heartdisease(0)      | heartdisease(1)      |
# +--------------+----------------------+----------------------+
# | chol(100)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(117)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(129)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(132)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(147)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(156)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(160)    | 0.012269938650306749 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(161)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(163)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(164)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(166)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(167)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(168)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(171)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(172)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(173)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(175)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(179)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(180)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(182)    | 0.012269938650306749 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(184)    | 0.018404907975460124 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(186)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(187)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(188)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(190)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(193)    | 0.006134969325153374 | 0.02040816326530612  |
# +--------------+----------------------+----------------------+
# | chol(194)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(195)    | 0.018404907975460124 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(196)    | 0.018404907975460124 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(198)    | 0.012269938650306749 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(200)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(201)    | 0.012269938650306749 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(202)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(204)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(205)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(206)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(207)    | 0.012269938650306749 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(208)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(209)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(210)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(211)    | 0.018404907975460124 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(212)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(213)    | 0.006134969325153374 | 0.02040816326530612  |
# +--------------+----------------------+----------------------+
# | chol(214)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(215)    | 0.024539877300613498 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(216)    | 0.012269938650306749 | 0.02040816326530612  |
# +--------------+----------------------+----------------------+
# | chol(217)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(218)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(219)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(220)    | 0.018404907975460124 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(221)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(222)    | 0.006134969325153374 | 0.02040816326530612  |
# +--------------+----------------------+----------------------+
# | chol(223)    | 0.012269938650306749 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(224)    | 0.018404907975460124 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(225)    | 0.012269938650306749 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(226)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(227)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(228)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(229)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(230)    | 0.024539877300613498 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(231)    | 0.0                  | 0.02040816326530612  |
# +--------------+----------------------+----------------------+
# | chol(233)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(234)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(237)    | 0.012269938650306749 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(238)    | 0.024539877300613498 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(240)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(241)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(242)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(243)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(245)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(246)    | 0.012269938650306749 | 0.030612244897959183 |
# +--------------+----------------------+----------------------+
# | chol(247)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(248)    | 0.0                  | 0.030612244897959183 |
# +--------------+----------------------+----------------------+
# | chol(249)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(250)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(251)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(253)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(254)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(255)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(256)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(257)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(259)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(260)    | 0.018404907975460124 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(263)    | 0.006134969325153374 | 0.030612244897959183 |
# +--------------+----------------------+----------------------+
# | chol(264)    | 0.006134969325153374 | 0.02040816326530612  |
# +--------------+----------------------+----------------------+
# | chol(265)    | 0.0                  | 0.02040816326530612  |
# +--------------+----------------------+----------------------+
# | chol(266)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(267)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(268)    | 0.006134969325153374 | 0.02040816326530612  |
# +--------------+----------------------+----------------------+
# | chol(269)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(270)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(271)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(272)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(273)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(274)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(275)    | 0.012269938650306749 | 0.02040816326530612  |
# +--------------+----------------------+----------------------+
# | chol(276)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(277)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(279)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(280)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(281)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(282)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(283)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(284)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(285)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(287)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(288)    | 0.0                  | 0.030612244897959183 |
# +--------------+----------------------+----------------------+
# | chol(289)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(290)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(291)    | 0.006134969325153374 | 0.02040816326530612  |
# +--------------+----------------------+----------------------+
# | chol(292)    | 0.012269938650306749 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(294)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(295)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(297)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(298)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(303)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(305)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(306)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(307)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(308)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(309)    | 0.0                  | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(312)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(315)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(318)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(320)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(326)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(328)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(329)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(331)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(336)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(338)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(339)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(340)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(341)    | 0.0                  | 0.02040816326530612  |
# +--------------+----------------------+----------------------+
# | chol(342)    | 0.0                  | 0.02040816326530612  |
# +--------------+----------------------+----------------------+
# | chol(344)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(347)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(355)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(358)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(365)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(388)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(392)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(393)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(394)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(404)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(412)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(466)    | 0.0                  | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(468)    | 0.0                  | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(491)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(518)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(529)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(603)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(85)     | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# +--------+----------+
# | sex(0) | 0.264368 |
# +--------+----------+
# | sex(1) | 0.735632 |
# +--------+----------+
# (age _|_ exang, sex)
# (age _|_ exang | sex)
# (age _|_ thalach, restecg, chol | heartdisease)
# (age _|_ sex | exang)
# (age _|_ exang, sex | fbs)
# (age _|_ thalach, restecg, chol | heartdisease, trestbps)
# (age _|_ chol, thalach, restecg, heartdisease | fbs, trestbps)
# (age _|_ restecg, chol | thalach, heartdisease)
# (age _|_ thalach, restecg, chol | sex, heartdisease)
# (age _|_ exang | fbs, sex)
# (age _|_ thalach, chol | restecg, heartdisease)
# (age _|_ thalach, restecg, chol | exang, heartdisease)
# (age _|_ thalach, restecg, chol | fbs, heartdisease)
# (age _|_ thalach, restecg | chol, heartdisease)
# (age _|_ sex | exang, fbs)
# (age _|_ restecg, chol | thalach, heartdisease, trestbps)
# (age _|_ chol, restecg, heartdisease | fbs, thalach, trestbps)
# (age _|_ thalach, restecg, chol | heartdisease, sex, trestbps)
# (age _|_ chol, thalach, restecg, heartdisease | fbs, sex, trestbps)
# (age _|_ thalach, chol | restecg, heartdisease, trestbps)
# (age _|_ thalach, restecg, chol | exang, heartdisease, trestbps)
# (age _|_ thalach, restecg, chol | fbs, heartdisease, trestbps)
# (age _|_ thalach, restecg | chol, heartdisease, trestbps)
# (age _|_ chol, thalach, heartdisease | fbs, restecg, trestbps)
# (age _|_ chol, thalach, restecg, heartdisease | exang, fbs, trestbps)
# (age _|_ thalach, restecg, heartdisease | chol, fbs, trestbps)
# (age _|_ restecg, chol | thalach, sex, heartdisease)
# (age _|_ chol | thalach, restecg, heartdisease)
# (age _|_ restecg, chol | exang, thalach, heartdisease)
# (age _|_ restecg, chol | fbs, thalach, heartdisease)
# (age _|_ restecg | chol, thalach, heartdisease)
# (age _|_ thalach, chol | restecg, sex, heartdisease)
# (age _|_ thalach, restecg, chol | exang, sex, heartdisease)
# (age _|_ thalach, restecg, chol | fbs, sex, heartdisease)
# (age _|_ thalach, restecg | chol, sex, heartdisease)
# (age _|_ thalach, chol | exang, restecg, heartdisease)
# (age _|_ thalach, chol | fbs, restecg, heartdisease)
# (age _|_ thalach | chol, restecg, heartdisease)
# (age _|_ thalach, restecg, chol | exang, fbs, heartdisease)
# (age _|_ thalach, restecg | chol, exang, heartdisease)
# (age _|_ thalach, restecg | chol, fbs, heartdisease)
# (age _|_ restecg, chol | heartdisease, thalach, sex, trestbps)
# (age _|_ heartdisease, restecg, chol | fbs, thalach, sex, trestbps)
# (age _|_ chol | restecg, thalach, heartdisease, trestbps)
# (age _|_ restecg, chol | exang, thalach, heartdisease, trestbps)
# (age _|_ restecg, chol | fbs, thalach, heartdisease, trestbps)
# (age _|_ restecg | chol, thalach, heartdisease, trestbps)
# (age _|_ heartdisease, chol | fbs, thalach, restecg, trestbps)
# (age _|_ heartdisease, restecg, chol | exang, fbs, thalach, trestbps)
# (age _|_ restecg, heartdisease | chol, fbs, thalach, trestbps)
# (age _|_ thalach, chol | restecg, heartdisease, sex, trestbps)
# (age _|_ thalach, restecg, chol | heartdisease, sex, trestbps, exang)
# (age _|_ thalach, restecg, chol | heartdisease, fbs, sex, trestbps)
# (age _|_ thalach, restecg | chol, heartdisease, sex, trestbps)
# (age _|_ thalach, heartdisease, chol | restecg, fbs, sex, trestbps)
# (age _|_ heartdisease, thalach, restecg, chol | exang, fbs, sex, trestbps)
# (age _|_ thalach, restecg, heartdisease | chol, fbs, sex, trestbps)
# (age _|_ thalach, chol | restecg, exang, heartdisease, trestbps)
# (age _|_ thalach, chol | restecg, fbs, heartdisease, trestbps)
# (age _|_ thalach | restecg, chol, heartdisease, trestbps)
# (age _|_ thalach, restecg, chol | exang, fbs, heartdisease, trestbps)
# (age _|_ thalach, restecg | chol, exang, heartdisease, trestbps)
# (age _|_ thalach, restecg | chol, fbs, heartdisease, trestbps)
# (age _|_ thalach, heartdisease, chol | exang, fbs, restecg, trestbps)
# (age _|_ thalach, heartdisease | chol, fbs, restecg, trestbps)
# (age _|_ thalach, restecg, heartdisease | chol, exang, fbs, trestbps)
# (age _|_ chol | restecg, thalach, sex, heartdisease)
# (age _|_ restecg, chol | exang, thalach, sex, heartdisease)
# (age _|_ restecg, chol | fbs, thalach, sex, heartdisease)
# (age _|_ restecg | chol, thalach, sex, heartdisease)
# (age _|_ chol | exang, thalach, restecg, heartdisease)
# (age _|_ chol | fbs, thalach, restecg, heartdisease)
# (age _|_ restecg, chol | exang, fbs, thalach, heartdisease)
# (age _|_ restecg | chol, exang, thalach, heartdisease)
# (age _|_ restecg | chol, fbs, thalach, heartdisease)
# (age _|_ thalach, chol | restecg, exang, sex, heartdisease)
# (age _|_ thalach, chol | restecg, fbs, sex, heartdisease)
# (age _|_ thalach | restecg, chol, sex, heartdisease)
# (age _|_ thalach, restecg, chol | exang, fbs, sex, heartdisease)
# (age _|_ thalach, restecg | chol, exang, sex, heartdisease)
# (age _|_ thalach, restecg | chol, fbs, sex, heartdisease)
# (age _|_ thalach, chol | exang, fbs, restecg, heartdisease)
# (age _|_ thalach | chol, exang, restecg, heartdisease)
# (age _|_ thalach | chol, fbs, restecg, heartdisease)
# (age _|_ thalach, restecg | chol, exang, fbs, heartdisease)
# (age _|_ chol | trestbps, thalach, restecg, heartdisease, sex)
# (age _|_ restecg, chol | trestbps, thalach, sex, heartdisease, exang)
# (age _|_ restecg, chol | trestbps, thalach, sex, heartdisease, fbs)
# (age _|_ restecg | trestbps, thalach, sex, heartdisease, chol)
# (age _|_ heartdisease, chol | trestbps, thalach, restecg, sex, fbs)
# (age _|_ heartdisease, restecg, chol | trestbps, thalach, sex, exang, fbs)
# (age _|_ restecg, heartdisease | trestbps, thalach, sex, fbs, chol)
# (age _|_ chol | trestbps, thalach, restecg, heartdisease, exang)
# (age _|_ chol | trestbps, thalach, restecg, heartdisease, fbs)
# (age _|_ restecg, chol | trestbps, thalach, heartdisease, exang, fbs)
# (age _|_ restecg | trestbps, thalach, heartdisease, exang, chol)
# (age _|_ restecg | trestbps, thalach, heartdisease, fbs, chol)
# (age _|_ heartdisease, chol | trestbps, thalach, restecg, exang, fbs)
# (age _|_ heartdisease | trestbps, thalach, restecg, fbs, chol)
# (age _|_ restecg, heartdisease | trestbps, thalach, exang, fbs, chol)
# (age _|_ thalach, chol | trestbps, restecg, heartdisease, sex, exang)
# (age _|_ thalach, chol | trestbps, restecg, heartdisease, sex, fbs)
# (age _|_ thalach | trestbps, restecg, heartdisease, sex, chol)
# (age _|_ thalach, restecg, chol | trestbps, sex, heartdisease, exang, fbs)
# (age _|_ thalach, restecg | trestbps, sex, heartdisease, exang, chol)
# (age _|_ thalach, restecg | trestbps, sex, heartdisease, fbs, chol)
# (age _|_ thalach, heartdisease, chol | trestbps, restecg, sex, exang, fbs)
# (age _|_ thalach, heartdisease | trestbps, restecg, sex, fbs, chol)
# (age _|_ thalach, restecg, heartdisease | trestbps, sex, exang, fbs, chol)
# (age _|_ thalach, chol | trestbps, restecg, heartdisease, exang, fbs)
# (age _|_ thalach | trestbps, restecg, heartdisease, exang, chol)
# (age _|_ thalach | trestbps, restecg, heartdisease, fbs, chol)
# (age _|_ thalach, restecg | trestbps, heartdisease, exang, fbs, chol)
# (age _|_ thalach, heartdisease | trestbps, restecg, exang, fbs, chol)
# (age _|_ chol | thalach, restecg, sex, heartdisease, exang)
# (age _|_ chol | thalach, restecg, sex, heartdisease, fbs)
# (age _|_ restecg, chol | thalach, sex, heartdisease, exang, fbs)
# (age _|_ restecg | thalach, sex, heartdisease, exang, chol)
# (age _|_ restecg | thalach, sex, heartdisease, fbs, chol)
# (age _|_ chol | thalach, restecg, heartdisease, exang, fbs)
# (age _|_ restecg | thalach, heartdisease, exang, fbs, chol)
# (age _|_ thalach, chol | restecg, sex, heartdisease, exang, fbs)
# (age _|_ thalach | restecg, sex, heartdisease, exang, chol)
# (age _|_ thalach | restecg, sex, heartdisease, fbs, chol)
# (age _|_ thalach, restecg | sex, heartdisease, exang, fbs, chol)
# (age _|_ thalach | restecg, heartdisease, exang, fbs, chol)
# (age _|_ chol | trestbps, thalach, restecg, heartdisease, sex, exang)
# (age _|_ chol | trestbps, thalach, restecg, heartdisease, sex, fbs)
# (age _|_ restecg, chol | trestbps, thalach, sex, heartdisease, exang, fbs)
# (age _|_ restecg | trestbps, thalach, sex, heartdisease, exang, chol)
# (age _|_ restecg | trestbps, thalach, sex, heartdisease, fbs, chol)
# (age _|_ heartdisease, chol | trestbps, thalach, restecg, sex, exang, fbs)
# (age _|_ heartdisease | trestbps, thalach, restecg, sex, fbs, chol)
# (age _|_ restecg, heartdisease | trestbps, thalach, sex, exang, fbs, chol)
# (age _|_ chol | trestbps, thalach, restecg, heartdisease, exang, fbs)
# (age _|_ restecg | trestbps, thalach, heartdisease, exang, fbs, chol)
# (age _|_ heartdisease | trestbps, thalach, restecg, exang, fbs, chol)
# (age _|_ thalach, chol | trestbps, restecg, heartdisease, sex, exang, fbs)
# (age _|_ thalach | trestbps, restecg, heartdisease, sex, exang, chol)
# (age _|_ thalach | trestbps, restecg, heartdisease, sex, fbs, chol)
# (age _|_ thalach, restecg | trestbps, sex, heartdisease, exang, fbs, chol)
# (age _|_ thalach, heartdisease | trestbps, restecg, sex, exang, fbs, chol)
# (age _|_ thalach | trestbps, restecg, heartdisease, exang, fbs, chol)
# (age _|_ chol | thalach, restecg, sex, heartdisease, exang, fbs)
# (age _|_ restecg | thalach, sex, heartdisease, exang, fbs, chol)
# (age _|_ thalach | restecg, sex, heartdisease, exang, fbs, chol)
# (age _|_ chol | trestbps, thalach, restecg, heartdisease, sex, exang, fbs)
# (age _|_ restecg | trestbps, thalach, sex, heartdisease, exang, fbs, chol)
# (age _|_ heartdisease | trestbps, thalach, restecg, sex, exang, fbs, chol)
# (age _|_ thalach | trestbps, restecg, heartdisease, sex, exang, fbs, chol)
# (trestbps _|_ thalach, restecg, chol | heartdisease)
# (trestbps _|_ fbs | age)
# (trestbps _|_ restecg, chol | thalach, heartdisease)
# (trestbps _|_ thalach, restecg, chol | sex, heartdisease)
# (trestbps _|_ fbs | age, sex)
# (trestbps _|_ thalach, chol | restecg, heartdisease)
# (trestbps _|_ thalach, restecg, chol | exang, heartdisease)
# (trestbps _|_ thalach, restecg, chol | fbs, heartdisease)
# (trestbps _|_ thalach, restecg, chol | age, heartdisease)
# (trestbps _|_ thalach, restecg | chol, heartdisease)
# (trestbps _|_ fbs | exang, age)
# (trestbps _|_ restecg, chol | thalach, sex, heartdisease)
# (trestbps _|_ chol | thalach, restecg, heartdisease)
# (trestbps _|_ restecg, chol | exang, thalach, heartdisease)
# (trestbps _|_ restecg, chol | fbs, thalach, heartdisease)
# (trestbps _|_ restecg, chol | age, thalach, heartdisease)
# (trestbps _|_ restecg | chol, thalach, heartdisease)
# (trestbps _|_ thalach, chol | restecg, sex, heartdisease)
# (trestbps _|_ thalach, restecg, chol | exang, sex, heartdisease)
# (trestbps _|_ thalach, restecg, chol | fbs, sex, heartdisease)
# (trestbps _|_ thalach, restecg, chol | age, sex, heartdisease)
# (trestbps _|_ thalach, restecg | chol, sex, heartdisease)
# (trestbps _|_ fbs | exang, age, sex)
# (trestbps _|_ thalach, chol | exang, restecg, heartdisease)
# (trestbps _|_ thalach, chol | fbs, restecg, heartdisease)
# (trestbps _|_ thalach, chol | age, restecg, heartdisease)
# (trestbps _|_ thalach | chol, restecg, heartdisease)
# (trestbps _|_ thalach, restecg, chol | exang, fbs, heartdisease)
# (trestbps _|_ thalach, restecg, chol | exang, age, heartdisease)
# (trestbps _|_ thalach, restecg | chol, exang, heartdisease)
# (trestbps _|_ thalach, restecg, chol | fbs, age, heartdisease)
# (trestbps _|_ thalach, restecg | chol, fbs, heartdisease)
# (trestbps _|_ thalach, restecg | chol, age, heartdisease)
# (trestbps _|_ chol | restecg, thalach, sex, heartdisease)
# (trestbps _|_ restecg, chol | exang, thalach, sex, heartdisease)
# (trestbps _|_ restecg, chol | fbs, thalach, sex, heartdisease)
# (trestbps _|_ restecg, chol | age, thalach, sex, heartdisease)
# (trestbps _|_ restecg | chol, thalach, sex, heartdisease)
# (trestbps _|_ chol | exang, thalach, restecg, heartdisease)
# (trestbps _|_ chol | fbs, thalach, restecg, heartdisease)
# (trestbps _|_ chol | age, thalach, restecg, heartdisease)
# (trestbps _|_ restecg, chol | exang, fbs, thalach, heartdisease)
# (trestbps _|_ restecg, chol | exang, age, thalach, heartdisease)
# (trestbps _|_ restecg | chol, exang, thalach, heartdisease)
# (trestbps _|_ restecg, chol | fbs, thalach, heartdisease, age)
# (trestbps _|_ restecg | chol, fbs, thalach, heartdisease)
# (trestbps _|_ restecg | chol, age, thalach, heartdisease)
# (trestbps _|_ thalach, chol | restecg, exang, sex, heartdisease)
# (trestbps _|_ thalach, chol | restecg, fbs, sex, heartdisease)
# (trestbps _|_ thalach, chol | restecg, age, sex, heartdisease)
# (trestbps _|_ thalach | restecg, chol, sex, heartdisease)
# (trestbps _|_ thalach, restecg, chol | exang, fbs, sex, heartdisease)
# (trestbps _|_ thalach, restecg, chol | exang, age, sex, heartdisease)
# (trestbps _|_ thalach, restecg | chol, exang, sex, heartdisease)
# (trestbps _|_ thalach, restecg, chol | fbs, age, sex, heartdisease)
# (trestbps _|_ thalach, restecg | chol, fbs, sex, heartdisease)
# (trestbps _|_ thalach, restecg | chol, age, sex, heartdisease)
# (trestbps _|_ thalach, chol | exang, fbs, restecg, heartdisease)
# (trestbps _|_ thalach, chol | exang, age, restecg, heartdisease)
# (trestbps _|_ thalach | chol, exang, restecg, heartdisease)
# (trestbps _|_ thalach, chol | fbs, age, restecg, heartdisease)
# (trestbps _|_ thalach | chol, fbs, restecg, heartdisease)
# (trestbps _|_ thalach | chol, age, restecg, heartdisease)
# (trestbps _|_ thalach, restecg, chol | exang, fbs, age, heartdisease)
# (trestbps _|_ thalach, restecg | chol, exang, fbs, heartdisease)
# (trestbps _|_ thalach, restecg | chol, exang, age, heartdisease)
# (trestbps _|_ thalach, restecg | chol, fbs, age, heartdisease)
# (trestbps _|_ chol | thalach, restecg, sex, heartdisease, exang)
# (trestbps _|_ chol | thalach, restecg, sex, heartdisease, fbs)
# (trestbps _|_ chol | thalach, restecg, sex, heartdisease, age)
# (trestbps _|_ restecg, chol | thalach, sex, heartdisease, exang, fbs)
# (trestbps _|_ restecg, chol | thalach, sex, heartdisease, exang, age)
# (trestbps _|_ restecg | thalach, sex, heartdisease, exang, chol)
# (trestbps _|_ restecg, chol | thalach, sex, heartdisease, fbs, age)
# (trestbps _|_ restecg | thalach, sex, heartdisease, fbs, chol)
# (trestbps _|_ restecg | thalach, sex, heartdisease, age, chol)
# (trestbps _|_ chol | thalach, restecg, heartdisease, exang, fbs)
# (trestbps _|_ chol | thalach, restecg, heartdisease, exang, age)
# (trestbps _|_ chol | thalach, restecg, heartdisease, fbs, age)
# (trestbps _|_ restecg, chol | thalach, heartdisease, exang, fbs, age)
# (trestbps _|_ restecg | thalach, heartdisease, exang, fbs, chol)
# (trestbps _|_ restecg | thalach, heartdisease, exang, age, chol)
# (trestbps _|_ restecg | thalach, heartdisease, fbs, age, chol)
# (trestbps _|_ thalach, chol | restecg, sex, heartdisease, exang, fbs)
# (trestbps _|_ thalach, chol | restecg, sex, heartdisease, exang, age)
# (trestbps _|_ thalach | restecg, sex, heartdisease, exang, chol)
# (trestbps _|_ thalach, chol | restecg, sex, heartdisease, fbs, age)
# (trestbps _|_ thalach | restecg, sex, heartdisease, fbs, chol)
# (trestbps _|_ thalach | restecg, sex, heartdisease, age, chol)
# (trestbps _|_ thalach, restecg, chol | sex, heartdisease, exang, fbs, age)
# (trestbps _|_ thalach, restecg | sex, heartdisease, exang, fbs, chol)
# (trestbps _|_ thalach, restecg | sex, heartdisease, exang, age, chol)
# (trestbps _|_ thalach, restecg | sex, heartdisease, fbs, age, chol)
# (trestbps _|_ thalach, chol | restecg, heartdisease, exang, fbs, age)
# (trestbps _|_ thalach | restecg, heartdisease, exang, fbs, chol)
# (trestbps _|_ thalach | restecg, heartdisease, exang, age, chol)
# (trestbps _|_ thalach | restecg, heartdisease, fbs, age, chol)
# (trestbps _|_ thalach, restecg | heartdisease, exang, fbs, age, chol)
# (trestbps _|_ chol | thalach, restecg, sex, heartdisease, exang, fbs)
# (trestbps _|_ chol | thalach, restecg, sex, heartdisease, exang, age)
# (trestbps _|_ chol | thalach, restecg, sex, heartdisease, fbs, age)
# (trestbps _|_ restecg, chol | thalach, sex, heartdisease, exang, fbs, age)
# (trestbps _|_ restecg | thalach, sex, heartdisease, exang, fbs, chol)
# (trestbps _|_ restecg | thalach, sex, heartdisease, exang, age, chol)
# (trestbps _|_ restecg | thalach, sex, heartdisease, fbs, age, chol)
# (trestbps _|_ chol | thalach, restecg, heartdisease, exang, fbs, age)
# (trestbps _|_ restecg | thalach, heartdisease, exang, fbs, age, chol)
# (trestbps _|_ thalach, chol | restecg, sex, heartdisease, exang, fbs, age)
# (trestbps _|_ thalach | restecg, sex, heartdisease, exang, fbs, chol)
# (trestbps _|_ thalach | restecg, sex, heartdisease, exang, age, chol)
# (trestbps _|_ thalach | restecg, sex, heartdisease, fbs, age, chol)
# (trestbps _|_ thalach, restecg | sex, heartdisease, exang, fbs, age, chol)
# (trestbps _|_ thalach | restecg, heartdisease, exang, fbs, age, chol)
# (trestbps _|_ chol | thalach, restecg, sex, heartdisease, exang, fbs, age)
# (trestbps _|_ restecg | thalach, sex, heartdisease, exang, fbs, age, chol)
# (trestbps _|_ thalach | restecg, sex, heartdisease, exang, fbs, age, chol)
# (fbs _|_ exang, sex)
# (fbs _|_ exang | sex)
# (fbs _|_ thalach, restecg, chol | heartdisease)
# (fbs _|_ sex | exang)
# (fbs _|_ exang, sex, trestbps | age)
# (fbs _|_ thalach, restecg, chol | heartdisease, trestbps)
# (fbs _|_ exang, sex | age, trestbps)
# (fbs _|_ restecg, chol | thalach, heartdisease)
# (fbs _|_ thalach, restecg, chol | sex, heartdisease)
# (fbs _|_ exang, trestbps | age, sex)
# (fbs _|_ thalach, chol | restecg, heartdisease)
# (fbs _|_ thalach, restecg, chol | exang, heartdisease)
# (fbs _|_ thalach, restecg, chol | age, heartdisease)
# (fbs _|_ thalach, restecg | chol, heartdisease)
# (fbs _|_ sex, trestbps | exang, age)
# (fbs _|_ restecg, chol | thalach, heartdisease, trestbps)
# (fbs _|_ exang, sex | age, thalach, trestbps)
# (fbs _|_ thalach, restecg, chol | heartdisease, sex, trestbps)
# (fbs _|_ exang | age, sex, trestbps)
# (fbs _|_ thalach, chol | restecg, heartdisease, trestbps)
# (fbs _|_ thalach, restecg, chol | exang, heartdisease, trestbps)
# (fbs _|_ exang, restecg, thalach, sex, chol | age, heartdisease, trestbps)
# (fbs _|_ thalach, restecg | chol, heartdisease, trestbps)
# (fbs _|_ exang, sex | age, restecg, trestbps)
# (fbs _|_ sex | exang, age, trestbps)
# (fbs _|_ exang, sex | chol, age, trestbps)
# (fbs _|_ restecg, chol | thalach, sex, heartdisease)
# (fbs _|_ chol | thalach, restecg, heartdisease)
# (fbs _|_ restecg, chol | exang, thalach, heartdisease)
# (fbs _|_ restecg, chol | age, thalach, heartdisease)
# (fbs _|_ restecg | chol, thalach, heartdisease)
# (fbs _|_ thalach, chol | restecg, sex, heartdisease)
# (fbs _|_ thalach, restecg, chol | exang, sex, heartdisease)
# (fbs _|_ thalach, restecg, chol | age, sex, heartdisease)
# (fbs _|_ thalach, restecg | chol, sex, heartdisease)
# (fbs _|_ trestbps | exang, age, sex)
# (fbs _|_ thalach, chol | exang, restecg, heartdisease)
# (fbs _|_ thalach, chol | age, restecg, heartdisease)
# (fbs _|_ thalach | chol, restecg, heartdisease)
# (fbs _|_ thalach, restecg, chol | exang, age, heartdisease)
# (fbs _|_ thalach, restecg | chol, exang, heartdisease)
# (fbs _|_ thalach, restecg | chol, age, heartdisease)
# (fbs _|_ restecg, chol | heartdisease, thalach, sex, trestbps)
# (fbs _|_ exang | age, thalach, sex, trestbps)
# (fbs _|_ chol | restecg, thalach, heartdisease, trestbps)
# (fbs _|_ restecg, chol | exang, thalach, heartdisease, trestbps)
# (fbs _|_ sex, exang, restecg, chol | age, thalach, heartdisease, trestbps)
# (fbs _|_ restecg | chol, thalach, heartdisease, trestbps)
# (fbs _|_ exang, sex | age, thalach, restecg, trestbps)
# (fbs _|_ sex | exang, age, thalach, trestbps)
# (fbs _|_ exang, sex | chol, age, thalach, trestbps)
# (fbs _|_ thalach, chol | restecg, heartdisease, sex, trestbps)
# (fbs _|_ thalach, restecg, chol | heartdisease, sex, trestbps, exang)
# (fbs _|_ exang, thalach, restecg, chol | heartdisease, age, sex, trestbps)
# (fbs _|_ thalach, restecg | chol, heartdisease, sex, trestbps)
# (fbs _|_ exang | restecg, age, sex, trestbps)
# (fbs _|_ exang | chol, age, sex, trestbps)
# (fbs _|_ thalach, chol | restecg, exang, heartdisease, trestbps)
# (fbs _|_ exang, thalach, sex, chol | restecg, age, heartdisease, trestbps)
# (fbs _|_ thalach | restecg, chol, heartdisease, trestbps)
# (fbs _|_ sex, thalach, restecg, chol | exang, age, heartdisease, trestbps)
# (fbs _|_ thalach, restecg | chol, exang, heartdisease, trestbps)
# (fbs _|_ sex, exang, thalach, restecg | chol, age, heartdisease, trestbps)
# (fbs _|_ sex | exang, age, restecg, trestbps)
# (fbs _|_ exang, sex | chol, age, restecg, trestbps)
# (fbs _|_ sex | chol, exang, age, trestbps)
# (fbs _|_ chol | restecg, thalach, sex, heartdisease)
# (fbs _|_ restecg, chol | exang, thalach, sex, heartdisease)
# (fbs _|_ restecg, chol | age, thalach, sex, heartdisease)
# (fbs _|_ restecg | chol, thalach, sex, heartdisease)
# (fbs _|_ chol | exang, thalach, restecg, heartdisease)
# (fbs _|_ chol | age, thalach, restecg, heartdisease)
# (fbs _|_ restecg, chol | exang, age, thalach, heartdisease)
# (fbs _|_ restecg | chol, exang, thalach, heartdisease)
# (fbs _|_ restecg | chol, age, thalach, heartdisease)
# (fbs _|_ thalach, chol | restecg, exang, sex, heartdisease)
# (fbs _|_ thalach, chol | restecg, age, sex, heartdisease)
# (fbs _|_ thalach | restecg, chol, sex, heartdisease)
# (fbs _|_ thalach, restecg, chol | exang, age, sex, heartdisease)
# (fbs _|_ thalach, restecg | chol, exang, sex, heartdisease)
# (fbs _|_ thalach, restecg | chol, age, sex, heartdisease)
# (fbs _|_ thalach, chol | exang, age, restecg, heartdisease)
# (fbs _|_ thalach | chol, exang, restecg, heartdisease)
# (fbs _|_ thalach | chol, age, restecg, heartdisease)
# (fbs _|_ thalach, restecg | chol, exang, age, heartdisease)
# (fbs _|_ chol | trestbps, thalach, restecg, heartdisease, sex)
# (fbs _|_ restecg, chol | trestbps, thalach, sex, heartdisease, exang)
# (fbs _|_ exang, restecg, chol | trestbps, thalach, sex, heartdisease, age)
# (fbs _|_ restecg | trestbps, thalach, sex, heartdisease, chol)
# (fbs _|_ exang | trestbps, thalach, restecg, sex, age)
# (fbs _|_ exang | trestbps, thalach, sex, age, chol)
# (fbs _|_ chol | trestbps, thalach, restecg, heartdisease, exang)
# (fbs _|_ exang, sex, chol | trestbps, thalach, restecg, heartdisease, age)
# (fbs _|_ sex, restecg, chol | trestbps, thalach, heartdisease, exang, age)
# (fbs _|_ restecg | trestbps, thalach, heartdisease, exang, chol)
# (fbs _|_ sex, exang, restecg | trestbps, thalach, heartdisease, age, chol)
# (fbs _|_ sex | trestbps, thalach, restecg, exang, age)
# (fbs _|_ exang, sex | trestbps, thalach, restecg, age, chol)
# (fbs _|_ sex | trestbps, thalach, exang, age, chol)
# (fbs _|_ thalach, chol | trestbps, restecg, heartdisease, sex, exang)
# (fbs _|_ exang, thalach, chol | trestbps, restecg, heartdisease, sex, age)
# (fbs _|_ thalach | trestbps, restecg, heartdisease, sex, chol)
# (fbs _|_ thalach, restecg, chol | trestbps, sex, heartdisease, exang, age)
# (fbs _|_ thalach, restecg | trestbps, sex, heartdisease, exang, chol)
# (fbs _|_ exang, thalach, restecg | trestbps, sex, heartdisease, age, chol)
# (fbs _|_ exang | trestbps, restecg, sex, age, chol)
# (fbs _|_ thalach, sex, chol | trestbps, restecg, heartdisease, exang, age)
# (fbs _|_ thalach | trestbps, restecg, heartdisease, exang, chol)
# (fbs _|_ exang, thalach, sex | trestbps, restecg, heartdisease, age, chol)
# (fbs _|_ sex, thalach, restecg | trestbps, heartdisease, exang, age, chol)
# (fbs _|_ sex | trestbps, restecg, exang, age, chol)
# (fbs _|_ chol | thalach, restecg, sex, heartdisease, exang)
# (fbs _|_ chol | thalach, restecg, sex, heartdisease, age)
# (fbs _|_ restecg, chol | thalach, sex, heartdisease, exang, age)
# (fbs _|_ restecg | thalach, sex, heartdisease, exang, chol)
# (fbs _|_ restecg | thalach, sex, heartdisease, age, chol)
# (fbs _|_ chol | thalach, restecg, heartdisease, exang, age)
# (fbs _|_ restecg | thalach, heartdisease, exang, age, chol)
# (fbs _|_ thalach, chol | restecg, sex, heartdisease, exang, age)
# (fbs _|_ thalach | restecg, sex, heartdisease, exang, chol)
# (fbs _|_ thalach | restecg, sex, heartdisease, age, chol)
# (fbs _|_ thalach, restecg | sex, heartdisease, exang, age, chol)
# (fbs _|_ thalach | restecg, heartdisease, exang, age, chol)
# (fbs _|_ chol | trestbps, thalach, restecg, heartdisease, sex, exang)
# (fbs _|_ exang, chol | trestbps, thalach, restecg, heartdisease, sex, age)
# (fbs _|_ restecg, chol | trestbps, thalach, sex, heartdisease, exang, age)
# (fbs _|_ restecg | trestbps, thalach, sex, heartdisease, exang, chol)
# (fbs _|_ exang, restecg | trestbps, thalach, sex, heartdisease, age, chol)
# (fbs _|_ exang | trestbps, thalach, restecg, sex, age, chol)
# (fbs _|_ sex, chol | trestbps, thalach, restecg, heartdisease, exang, age)
# (fbs _|_ exang, sex | trestbps, thalach, restecg, heartdisease, age, chol)
# (fbs _|_ sex, restecg | trestbps, thalach, heartdisease, exang, age, chol)
# (fbs _|_ sex | trestbps, thalach, restecg, exang, age, chol)
# (fbs _|_ thalach, chol | trestbps, restecg, heartdisease, sex, exang, age)
# (fbs _|_ thalach | trestbps, restecg, heartdisease, sex, exang, chol)
# (fbs _|_ exang, thalach | trestbps, restecg, heartdisease, sex, age, chol)
# (fbs _|_ thalach, restecg | trestbps, sex, heartdisease, exang, age, chol)
# (fbs _|_ thalach, sex | trestbps, restecg, heartdisease, exang, age, chol)
# (fbs _|_ chol | thalach, restecg, sex, heartdisease, exang, age)
# (fbs _|_ restecg | thalach, sex, heartdisease, exang, age, chol)
# (fbs _|_ thalach | restecg, sex, heartdisease, exang, age, chol)
# (fbs _|_ chol | trestbps, thalach, restecg, heartdisease, sex, exang, age)
# (fbs _|_ exang | trestbps, thalach, restecg, heartdisease, sex, age, chol)
# (fbs _|_ restecg | trestbps, thalach, sex, heartdisease, exang, age, chol)
# (fbs _|_ sex | trestbps, thalach, restecg, heartdisease, exang, age, chol)
# (fbs _|_ thalach | trestbps, restecg, heartdisease, sex, exang, age, chol)
# (sex _|_ exang, fbs, age)
# (sex _|_ thalach, restecg, chol | heartdisease)
# (sex _|_ fbs, age | exang)
# (sex _|_ exang, age | fbs)
# (sex _|_ exang, fbs | age)
# ...
# (thalach _|_ age, sex, chol | trestbps, restecg, heartdisease, exang, fbs)
# (thalach _|_ fbs, sex, chol | trestbps, restecg, heartdisease, exang, age)
# (thalach _|_ fbs, age, sex | trestbps, restecg, heartdisease, exang, chol)
# (thalach _|_ exang, sex, chol | trestbps, restecg, heartdisease, fbs, age)
# (thalach _|_ exang, age, sex | trestbps, restecg, heartdisease, fbs, chol)
# (thalach _|_ exang, fbs, sex | trestbps, restecg, heartdisease, age, chol)
# (thalach _|_ sex, restecg, chol | trestbps, heartdisease, exang, fbs, age)
# (thalach _|_ sex, age, restecg | trestbps, heartdisease, exang, fbs, chol)
# (thalach _|_ sex, fbs, restecg | trestbps, heartdisease, exang, age, chol)
# (thalach _|_ sex, exang, restecg | trestbps, heartdisease, fbs, age, chol)
# (thalach _|_ sex | trestbps, restecg, exang, fbs, age)
# (thalach _|_ age, sex | trestbps, restecg, exang, fbs, chol)
# (thalach _|_ sex | trestbps, restecg, exang, age, chol)
# (thalach _|_ exang, sex | trestbps, restecg, fbs, age, chol)
# (thalach _|_ sex | trestbps, exang, fbs, age, chol)
# (thalach _|_ trestbps, age, chol | restecg, sex, heartdisease, exang, fbs)
# (thalach _|_ trestbps, fbs, chol | restecg, sex, heartdisease, exang, age)
# (thalach _|_ fbs, age, trestbps | restecg, sex, heartdisease, exang, chol)
# (thalach _|_ exang, trestbps, chol | restecg, sex, heartdisease, fbs, age)
# (thalach _|_ exang, age, trestbps | restecg, sex, heartdisease, fbs, chol)
# (thalach _|_ exang, fbs, trestbps | restecg, sex, heartdisease, age, chol)
# (thalach _|_ trestbps, restecg, chol | sex, heartdisease, exang, fbs, age)
# (thalach _|_ age, restecg, trestbps | sex, heartdisease, exang, fbs, chol)
# (thalach _|_ fbs, restecg, trestbps | sex, heartdisease, exang, age, chol)
# (thalach _|_ exang, restecg, trestbps | sex, heartdisease, fbs, age, chol)
# (thalach _|_ trestbps, sex, chol | restecg, heartdisease, exang, fbs, age)
# (thalach _|_ age, sex, trestbps | restecg, heartdisease, exang, fbs, chol)
# (thalach _|_ fbs, sex, trestbps | restecg, heartdisease, exang, age, chol)
# (thalach _|_ exang, sex, trestbps | restecg, heartdisease, fbs, age, chol)
# (thalach _|_ sex, restecg, trestbps | heartdisease, exang, fbs, age, chol)
# (thalach _|_ age, chol | trestbps, restecg, heartdisease, sex, exang, fbs)
# (thalach _|_ fbs, chol | trestbps, restecg, heartdisease, sex, exang, age)
# (thalach _|_ fbs, age | trestbps, restecg, heartdisease, sex, exang, chol)
# (thalach _|_ exang, chol | trestbps, restecg, heartdisease, sex, fbs, age)
# (thalach _|_ exang, age | trestbps, restecg, heartdisease, sex, fbs, chol)
# (thalach _|_ exang, fbs | trestbps, restecg, heartdisease, sex, age, chol)
# (thalach _|_ restecg, chol | trestbps, sex, heartdisease, exang, fbs, age)
# (thalach _|_ age, restecg | trestbps, sex, heartdisease, exang, fbs, chol)
# (thalach _|_ fbs, restecg | trestbps, sex, heartdisease, exang, age, chol)
# (thalach _|_ exang, restecg | trestbps, sex, heartdisease, fbs, age, chol)
# (thalach _|_ age | trestbps, restecg, sex, exang, fbs, chol)
# (thalach _|_ exang | trestbps, restecg, sex, fbs, age, chol)
# (thalach _|_ sex, chol | trestbps, restecg, heartdisease, exang, fbs, age)
# (thalach _|_ age, sex | trestbps, restecg, heartdisease, exang, fbs, chol)
# (thalach _|_ fbs, sex | trestbps, restecg, heartdisease, exang, age, chol)
# (thalach _|_ exang, sex | trestbps, restecg, heartdisease, fbs, age, chol)
# (thalach _|_ sex, restecg | trestbps, heartdisease, exang, fbs, age, chol)
# (thalach _|_ sex | trestbps, restecg, exang, fbs, age, chol)
# (thalach _|_ trestbps, chol | restecg, sex, heartdisease, exang, fbs, age)
# (thalach _|_ age, trestbps | restecg, sex, heartdisease, exang, fbs, chol)
# (thalach _|_ fbs, trestbps | restecg, sex, heartdisease, exang, age, chol)
# (thalach _|_ exang, trestbps | restecg, sex, heartdisease, fbs, age, chol)
# (thalach _|_ restecg, trestbps | sex, heartdisease, exang, fbs, age, chol)
# (thalach _|_ sex, trestbps | restecg, heartdisease, exang, fbs, age, chol)
# (thalach _|_ chol | trestbps, restecg, heartdisease, sex, exang, fbs, age)
# (thalach _|_ age | trestbps, restecg, heartdisease, sex, exang, fbs, chol)
# (thalach _|_ fbs | trestbps, restecg, heartdisease, sex, exang, age, chol)
# (thalach _|_ exang | trestbps, restecg, heartdisease, sex, fbs, age, chol)
# (thalach _|_ restecg | trestbps, sex, heartdisease, exang, fbs, age, chol)
# (thalach _|_ sex | trestbps, restecg, heartdisease, exang, fbs, age, chol)
# (thalach _|_ trestbps | restecg, sex, heartdisease, exang, fbs, age, chol)
# (chol _|_ exang, fbs, trestbps, sex, age, thalach, restecg | heartdisease)
# (chol _|_ exang, fbs, restecg, age, thalach, sex | heartdisease, trestbps)
# (chol _|_ exang, age, sex | fbs, trestbps)
# (chol _|_ exang, sex | age, trestbps)
# (chol _|_ exang, fbs, trestbps, restecg, age, sex | thalach, heartdisease)
# (chol _|_ exang, fbs, trestbps, age, thalach, restecg | sex, heartdisease)
# (chol _|_ exang, fbs, trestbps, age, thalach, sex | restecg, heartdisease)
# (chol _|_ fbs, trestbps, restecg, age, thalach, sex | exang, heartdisease)
# (chol _|_ exang, trestbps, restecg, age, thalach, sex | fbs, heartdisease)
# (chol _|_ exang, fbs, trestbps, restecg, thalach, sex | age, heartdisease)
# (chol _|_ exang, fbs, restecg, age, sex | thalach, heartdisease, trestbps)
# (chol _|_ exang, age, sex | fbs, thalach, trestbps)
# (chol _|_ exang, sex | age, thalach, trestbps)
# (chol _|_ exang, fbs, age, thalach, restecg | heartdisease, sex, trestbps)
# (chol _|_ exang, age | fbs, sex, trestbps)
# (chol _|_ exang | age, sex, trestbps)
# (chol _|_ exang, fbs, age, thalach, sex | restecg, heartdisease, trestbps)
# (chol _|_ fbs, restecg, age, thalach, sex | exang, heartdisease, trestbps)
# (chol _|_ exang, restecg, age, thalach, sex | fbs, heartdisease, trestbps)
# (chol _|_ exang, fbs, restecg, thalach, sex | age, heartdisease, trestbps)
# (chol _|_ exang, age, sex | fbs, restecg, trestbps)
# (chol _|_ exang, sex | age, restecg, trestbps)
# (chol _|_ age, sex | exang, fbs, trestbps)
# (chol _|_ sex | exang, age, trestbps)
# (chol _|_ exang, sex | fbs, age, trestbps)
# (chol _|_ exang, fbs, trestbps, age, restecg | thalach, sex, heartdisease)
# (chol _|_ exang, fbs, trestbps, age, sex | thalach, restecg, heartdisease)
# (chol _|_ fbs, trestbps, restecg, age, sex | exang, thalach, heartdisease)
# (chol _|_ exang, trestbps, restecg, age, sex | fbs, thalach, heartdisease)
# (chol _|_ exang, fbs, trestbps, restecg, sex | age, thalach, heartdisease)
# (chol _|_ exang, fbs, trestbps, age, thalach | restecg, sex, heartdisease)
# (chol _|_ fbs, trestbps, age, thalach, restecg | exang, sex, heartdisease)
# (chol _|_ exang, trestbps, age, thalach, restecg | fbs, sex, heartdisease)
# (chol _|_ exang, fbs, trestbps, thalach, restecg | age, sex, heartdisease)
# (chol _|_ fbs, trestbps, age, thalach, sex | exang, restecg, heartdisease)
# (chol _|_ exang, trestbps, age, thalach, sex | fbs, restecg, heartdisease)
# (chol _|_ exang, fbs, trestbps, thalach, sex | age, restecg, heartdisease)
# (chol _|_ trestbps, restecg, age, thalach, sex | exang, fbs, heartdisease)
# (chol _|_ fbs, trestbps, restecg, thalach, sex | exang, age, heartdisease)
# (chol _|_ exang, trestbps, restecg, thalach, sex | fbs, age, heartdisease)
# (chol _|_ exang, fbs, age, restecg | heartdisease, thalach, sex, trestbps)
# (chol _|_ exang, age | fbs, thalach, sex, trestbps)
# (chol _|_ exang | age, thalach, sex, trestbps)
# (chol _|_ exang, fbs, age, sex | restecg, thalach, heartdisease, trestbps)
# (chol _|_ sex, fbs, age, restecg | exang, thalach, heartdisease, trestbps)
# (chol _|_ sex, exang, age, restecg | fbs, thalach, heartdisease, trestbps)
# (chol _|_ sex, exang, fbs, restecg | age, thalach, heartdisease, trestbps)
# (chol _|_ exang, age, sex | fbs, thalach, restecg, trestbps)
# (chol _|_ exang, sex | age, thalach, restecg, trestbps)
# (chol _|_ age, sex | exang, fbs, thalach, trestbps)
# (chol _|_ sex | exang, age, thalach, trestbps)
# (chol _|_ exang, sex | fbs, thalach, trestbps, age)
# (chol _|_ exang, fbs, thalach, age | restecg, heartdisease, sex, trestbps)
# (chol _|_ fbs, thalach, restecg, age | heartdisease, sex, trestbps, exang)
# (chol _|_ exang, age, thalach, restecg | heartdisease, fbs, sex, trestbps)
# (chol _|_ exang, fbs, thalach, restecg | heartdisease, age, sex, trestbps)
# (chol _|_ exang, age | restecg, fbs, sex, trestbps)
# (chol _|_ exang | restecg, age, sex, trestbps)
# (chol _|_ age | exang, fbs, sex, trestbps)
# (chol _|_ exang | fbs, age, sex, trestbps)
# (chol _|_ fbs, thalach, sex, age | restecg, exang, heartdisease, trestbps)
# (chol _|_ exang, age, thalach, sex | restecg, fbs, heartdisease, trestbps)
# (chol _|_ exang, fbs, thalach, sex | restecg, age, heartdisease, trestbps)
# (chol _|_ sex, age, thalach, restecg | exang, fbs, heartdisease, trestbps)
# (chol _|_ sex, fbs, thalach, restecg | exang, age, heartdisease, trestbps)
# (chol _|_ sex, exang, thalach, restecg | fbs, age, heartdisease, trestbps)
# (chol _|_ age, sex | exang, fbs, restecg, trestbps)
# (chol _|_ sex | exang, age, restecg, trestbps)
# (chol _|_ exang, sex | fbs, age, restecg, trestbps)
# (chol _|_ sex | exang, fbs, age, trestbps)
# (chol _|_ exang, fbs, age, trestbps | restecg, thalach, sex, heartdisease)
# (chol _|_ fbs, age, restecg, trestbps | exang, thalach, sex, heartdisease)
# (chol _|_ exang, age, restecg, trestbps | fbs, thalach, sex, heartdisease)
# (chol _|_ exang, fbs, restecg, trestbps | age, thalach, sex, heartdisease)
# (chol _|_ fbs, age, sex, trestbps | exang, thalach, restecg, heartdisease)
# (chol _|_ exang, age, sex, trestbps | fbs, thalach, restecg, heartdisease)
# (chol _|_ exang, fbs, sex, trestbps | age, thalach, restecg, heartdisease)
# (chol _|_ sex, age, restecg, trestbps | exang, fbs, thalach, heartdisease)
# (chol _|_ sex, fbs, restecg, trestbps | exang, age, thalach, heartdisease)
# (chol _|_ sex, exang, restecg, trestbps | fbs, thalach, heartdisease, age)
# (chol _|_ fbs, thalach, trestbps, age | restecg, exang, sex, heartdisease)
# (chol _|_ exang, age, thalach, trestbps | restecg, fbs, sex, heartdisease)
# (chol _|_ exang, fbs, thalach, trestbps | restecg, age, sex, heartdisease)
# (chol _|_ age, thalach, restecg, trestbps | exang, fbs, sex, heartdisease)
# (chol _|_ fbs, thalach, restecg, trestbps | exang, age, sex, heartdisease)
# (chol _|_ exang, thalach, restecg, trestbps | fbs, age, sex, heartdisease)
# (chol _|_ age, thalach, sex, trestbps | exang, fbs, restecg, heartdisease)
# (chol _|_ fbs, thalach, sex, trestbps | exang, age, restecg, heartdisease)
# (chol _|_ exang, thalach, sex, trestbps | fbs, age, restecg, heartdisease)
# (chol _|_ sex, thalach, restecg, trestbps | exang, fbs, age, heartdisease)
# (chol _|_ exang, fbs, age | trestbps, thalach, restecg, heartdisease, sex)
# (chol _|_ fbs, age, restecg | trestbps, thalach, sex, heartdisease, exang)
# (chol _|_ exang, age, restecg | trestbps, thalach, sex, heartdisease, fbs)
# (chol _|_ exang, fbs, restecg | trestbps, thalach, sex, heartdisease, age)
# (chol _|_ exang, age | trestbps, thalach, restecg, sex, fbs)
# (chol _|_ exang | trestbps, thalach, restecg, sex, age)
# (chol _|_ age | trestbps, thalach, sex, exang, fbs)
# (chol _|_ exang | trestbps, thalach, sex, fbs, age)
# (chol _|_ fbs, age, sex | trestbps, thalach, restecg, heartdisease, exang)
# (chol _|_ exang, age, sex | trestbps, thalach, restecg, heartdisease, fbs)
# (chol _|_ exang, fbs, sex | trestbps, thalach, restecg, heartdisease, age)
# (chol _|_ sex, age, restecg | trestbps, thalach, heartdisease, exang, fbs)
# (chol _|_ sex, fbs, restecg | trestbps, thalach, heartdisease, exang, age)
# (chol _|_ sex, exang, restecg | trestbps, thalach, heartdisease, fbs, age)
# (chol _|_ age, sex | trestbps, thalach, restecg, exang, fbs)
# (chol _|_ sex | trestbps, thalach, restecg, exang, age)
# (chol _|_ exang, sex | trestbps, thalach, restecg, fbs, age)
# (chol _|_ sex | trestbps, thalach, exang, fbs, age)
# (chol _|_ fbs, thalach, age | trestbps, restecg, heartdisease, sex, exang)
# (chol _|_ exang, age, thalach | trestbps, restecg, heartdisease, sex, fbs)
# (chol _|_ exang, fbs, thalach | trestbps, restecg, heartdisease, sex, age)
# (chol _|_ age, thalach, restecg | trestbps, sex, heartdisease, exang, fbs)
# (chol _|_ fbs, thalach, restecg | trestbps, sex, heartdisease, exang, age)
# (chol _|_ exang, thalach, restecg | trestbps, sex, heartdisease, fbs, age)
# (chol _|_ age | trestbps, restecg, sex, exang, fbs)
# (chol _|_ exang | trestbps, restecg, sex, fbs, age)
# (chol _|_ age, thalach, sex | trestbps, restecg, heartdisease, exang, fbs)
# (chol _|_ fbs, thalach, sex | trestbps, restecg, heartdisease, exang, age)
# (chol _|_ exang, thalach, sex | trestbps, restecg, heartdisease, fbs, age)
# (chol _|_ sex, thalach, restecg | trestbps, heartdisease, exang, fbs, age)
# (chol _|_ sex | trestbps, restecg, exang, fbs, age)
# (chol _|_ fbs, age, trestbps | thalach, restecg, sex, heartdisease, exang)
# (chol _|_ exang, age, trestbps | thalach, restecg, sex, heartdisease, fbs)
# (chol _|_ exang, fbs, trestbps | thalach, restecg, sex, heartdisease, age)
# (chol _|_ age, restecg, trestbps | thalach, sex, heartdisease, exang, fbs)
# (chol _|_ fbs, restecg, trestbps | thalach, sex, heartdisease, exang, age)
# (chol _|_ exang, restecg, trestbps | thalach, sex, heartdisease, fbs, age)
# (chol _|_ age, sex, trestbps | thalach, restecg, heartdisease, exang, fbs)
# (chol _|_ fbs, sex, trestbps | thalach, restecg, heartdisease, exang, age)
# (chol _|_ exang, sex, trestbps | thalach, restecg, heartdisease, fbs, age)
# (chol _|_ sex, restecg, trestbps | thalach, heartdisease, exang, fbs, age)
# (chol _|_ age, thalach, trestbps | restecg, sex, heartdisease, exang, fbs)
# (chol _|_ fbs, thalach, trestbps | restecg, sex, heartdisease, exang, age)
# (chol _|_ exang, thalach, trestbps | restecg, sex, heartdisease, fbs, age)
# (chol _|_ thalach, restecg, trestbps | sex, heartdisease, exang, fbs, age)
# (chol _|_ thalach, sex, trestbps | restecg, heartdisease, exang, fbs, age)
# (chol _|_ fbs, age | trestbps, thalach, restecg, heartdisease, sex, exang)
# (chol _|_ exang, age | trestbps, thalach, restecg, heartdisease, sex, fbs)
# (chol _|_ exang, fbs | trestbps, thalach, restecg, heartdisease, sex, age)
# (chol _|_ age, restecg | trestbps, thalach, sex, heartdisease, exang, fbs)
# (chol _|_ fbs, restecg | trestbps, thalach, sex, heartdisease, exang, age)
# (chol _|_ exang, restecg | trestbps, thalach, sex, heartdisease, fbs, age)
# (chol _|_ age | trestbps, thalach, restecg, sex, exang, fbs)
# (chol _|_ exang | trestbps, thalach, restecg, sex, fbs, age)
# (chol _|_ age, sex | trestbps, thalach, restecg, heartdisease, exang, fbs)
# (chol _|_ fbs, sex | trestbps, thalach, restecg, heartdisease, exang, age)
# (chol _|_ exang, sex | trestbps, thalach, restecg, heartdisease, fbs, age)
# (chol _|_ sex, restecg | trestbps, thalach, heartdisease, exang, fbs, age)
# (chol _|_ sex | trestbps, thalach, restecg, exang, fbs, age)
# (chol _|_ age, thalach | trestbps, restecg, heartdisease, sex, exang, fbs)
# (chol _|_ fbs, thalach | trestbps, restecg, heartdisease, sex, exang, age)
# (chol _|_ exang, thalach | trestbps, restecg, heartdisease, sex, fbs, age)
# (chol _|_ thalach, restecg | trestbps, sex, heartdisease, exang, fbs, age)
# (chol _|_ thalach, sex | trestbps, restecg, heartdisease, exang, fbs, age)
# (chol _|_ age, trestbps | thalach, restecg, sex, heartdisease, exang, fbs)
# (chol _|_ fbs, trestbps | thalach, restecg, sex, heartdisease, exang, age)
# (chol _|_ exang, trestbps | thalach, restecg, sex, heartdisease, fbs, age)
# (chol _|_ restecg, trestbps | thalach, sex, heartdisease, exang, fbs, age)
# (chol _|_ sex, trestbps | thalach, restecg, heartdisease, exang, fbs, age)
# (chol _|_ thalach, trestbps | restecg, sex, heartdisease, exang, fbs, age)
# (chol _|_ age | trestbps, thalach, restecg, heartdisease, sex, exang, fbs)
# (chol _|_ fbs | trestbps, thalach, restecg, heartdisease, sex, exang, age)
# (chol _|_ exang | trestbps, thalach, restecg, heartdisease, sex, fbs, age)
# (chol _|_ restecg | trestbps, thalach, sex, heartdisease, exang, fbs, age)
# (chol _|_ sex | trestbps, thalach, restecg, heartdisease, exang, fbs, age)
# (chol _|_ thalach | trestbps, restecg, heartdisease, sex, exang, fbs, age)
# (chol _|_ trestbps | thalach, restecg, sex, heartdisease, exang, fbs, age)
